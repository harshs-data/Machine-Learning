# %% [markdown]
# <a href="https://colab.research.google.com/github/harshs-data/Machine-Learning/blob/main/SimpleLinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/placement.csv')
df.head(10)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57
# 5  7.89     2.99
# 6  6.73     2.60
# 7  6.75     2.48
# 8  6.09     2.31
# 9  8.31     3.51

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('cgpa')
plt.ylabel('package in (LPA)')
# Out:
# Text(0, 0.5, 'package in (LPA)')

# %%
X = df.iloc[:,:1]
y = df.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 2)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test.iloc[1].values.reshape(1,1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.09324469])

# %%
X_test.head()
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57

# %%
y_test.head()
# Out:
# 112    4.10
# 29     3.49
# 182    2.08
# 199    2.33
# 193    1.94
# Name: package, dtype: float64

# %%
plt.scatter(df['cgpa'], df['package'])
plt.plot(X_train,lr.predict(X_train), color = 'red')
plt.xlabel('cgpa')
plt.ylabel('package')
# Out:
# Text(0, 0.5, 'package')

# %%
m = lr.coef_

# %%
b = lr.intercept_

# %%
# y = mx + b

m * 8.58 + b
# Out:
# array([3.89111601])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
 y_pred = lr.predict(X_test)
 y_pred
# Out:
# array([3.89111601, 3.09324469, 2.38464568, 2.57434935, 1.6537286 ,
#        1.77647803, 2.07219258, 2.93143862, 3.76278706, 2.93701814,
#        4.09197872, 3.51170867, 2.97049525, 2.40138424, 3.18809652,
#        3.46707251, 1.94386362, 3.24389172, 2.97607477, 3.41685683,
#        2.55761079, 3.16577844, 2.85890486, 3.12114229, 3.68467378,
#        2.8700639 , 3.49497011, 3.34432308, 3.91901361, 1.96060218,
#        3.65119666, 3.2104146 , 3.74046898, 2.7863711 , 2.78079158,
#        3.27178932, 3.52844723, 2.61340599, 2.65804215, 2.71383735])

# %%
y_test.values
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61])

# %%
print('MAE', mean_absolute_error(y_test,y_pred))
# Out:
# MAE 0.2884710931878175

# %%
print('MSE', mean_squared_error(y_test, y_pred))
# Out:
# MSE 0.12129235313495527

# %%
print('MSE', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# MSE 0.34827051717731616

# %%
print('R2score', r2_score(y_test,y_pred))
# Out:
# R2score 0.780730147510384

# %% [markdown]
# ### Manual code for LinearRegression

# %%
class MeraLR:

  def __init__ (self):
    self.m = None
    self.b = None

  def fit(self, X_test, y_test):
    num = 0
    den = 0
    for i in range(X_train.shape[0]):

      num = num + ((X_train[i] - X_train.mean()) * (y_train[i] - y_train.mean()))
      den = den + ((X_train[i] - X_train.mean()) * (X_train[i] - X_train.mean()))

    self.m = num/den
    self.b = y_train.mean() - (self.m * X_train.mean())
    print(self.m)
    print(self.b)


  def predict(self, X_test):
    return self.m * X_test + self.b

# %%
import numpy as np
import pandas as pd

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
X = df.iloc[:,0].values
y = df.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train.shape
# Out:
# (160,)

# %%
lr = MeraLR()

# %%
lr.fit(X_train, y_train)
# Out:
# 0.5579519734250721
# -0.8961119222429152

# %%
y_test[0]
# Out:
# np.float64(4.1)

# %%
print(lr.predict(X_test[0]))
# Out:
# 3.891116009744203
