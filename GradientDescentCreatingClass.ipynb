# %% [markdown]
# <a href="https://colab.research.google.com/github/harshs-data/Machine-Learning/blob/main/GradientDescentCreatingClass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_regression
import numpy as np
import matplotlib.pyplot as plt

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1,noise=20)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [35.69439913]
# 3.094738109064652

# %%
class GDRegressor:

  def __init__(self,learning_rate,epochs):
    self.m = 92.6059675
    self.b = -120
    self.learning_rate = learning_rate
    self.epochs = epochs

  def fit(self,X,y):
    # calculate the b using GD
    for i in range(self.epochs):
        loss_slope = -2 * np.sum(y - self.m*X.ravel() - self.b)
        self.b = self.b - (self.learning_rate * loss_slope)
        print(self.b)
    print(self.b)

# %%
gd = GDRegressor(0.001,100)

# %%
gd.fit(X,y)
# Out:
# -96.68657741479458
# -78.03583934663024
# -63.115248892098776
# -51.178776528473605
# -41.629598637573466
# -33.990256324853355
# -27.878782474677266
# -22.989603394536392
# -19.078260130423693
# -15.949185519133534
# -13.445925830101407
# -11.443318078875706
# -9.841231877895144
# -8.559562917110695
# -7.534227748483135
# -6.713959613581087
# -6.05774510565945
# -5.532773499322139
# -5.112796214252291
# -4.7768143861964125
# -4.508028923751709
# -4.293000553795947
# -4.1209778578313365
# -3.9833597010596486
# -3.873265175642298
# -3.785189555308418
# -3.714729059041314
# -3.6583606620276305
# -3.6132659444166837
# -3.5771901703279267
# -3.548329551056921
# -3.525241055640116
# -3.506770259306672
# -3.4919936222399173
# -3.480172312586513
# -3.47071526486379
# -3.463149626685612
# -3.457097116143069
# -3.4522551077090347
# -3.4483815009618075
# -3.445282615564026
# -3.4428035072458005
# -3.4408202205912204
# -3.439233591267556
# -3.4379642878086245
# -3.4369488450414787
# ...

# %% [markdown]
# ### Gradient descent for m and b random value

# %%
from sklearn.datasets import make_regression
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1,noise=20, random_state=13)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [27.82809103]
# -2.29474455867698

# %%
np.mean(cross_val_score(lr,X,y,scoring='r2',cv=10))
# Out:
# np.float64(0.6375011587464419)

# %%
class GDRegressor:

  def __init__(self, learning_rate, epochs):
    self.m = 1
    self.b = 0
    self.lr = learning_rate
    self.epochs = epochs

  def fit(self, X, y):
    for i in range(self.epochs):
      loss_slope_b = -2 * np.sum(y - self.m*X.ravel() - self.b)
      loss_slope_m = -2 * np.sum((y - self.m*X.ravel() - self.b)*X.ravel())
      self.b = self.b - (self.lr * loss_slope_b)
      self.m = self.m - (self.lr * loss_slope_m)
    print(f"m : {self.m} , b : {self.b}")

# %%
gd = GDRegressor(0.001,100)

# %%
gd.fit(X,y)
# Out:
# m : 27.82809083367177 , b : -2.2947444825773005
